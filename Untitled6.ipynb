# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
import statsmodels.formula.api as smf
import seaborn as sns

# %%
dataset = pd.read_csv('C:/Users/omer qureshi/Downloads/Prob-8-1.csv')

# %%
dataset.head()
# Out:
#            y  x
# 0  35.367731  1
# 1  37.918217  2
# 2  31.321857  3
# 3  41.976404  4
# 4  34.147539  5

# %%
dataset.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 2 columns):
# y    16 non-null float64
# x    16 non-null int64
# dtypes: float64(1), int64(1)
# memory usage: 296.0 bytes

# %%
dataset.describe().T
# Out:
#    count       mean       std       min        25%        50%        75%  \
# y   16.0  27.708659  8.803849  7.926501  23.385957  30.218906  32.489744
# x   16.0   8.500000  4.760952  1.000000   4.750000   8.500000  12.250000
#
#          max
# y  41.976404
# x  16.000000

# %%
#Drawing scatterplot
plt.scatter(dataset.y, dataset.x, color='r')
#plt.scatter(dataset.y, dataset.x, color='g')
plt.xlabel('y')
plt.ylabel('x')
plt.show()

# %%
#Scatterplot
sns.catplot(x="x", y="y", data=dataset);

# %%
#sns.relplot(y="y",x="x", data=dataset);

# %%
#Running the regression
lm_stats = smf.ols(formula='dataset.y ~ dataset.x', data=dataset).fit()
print (lm_stats.summary())
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1394: UserWarning: kurtosistest only valid for n>=20 ... continuing anyway, n=16
#   "anyway, n=%i" % int(n))
#                             OLS Regression Results
# ...
# Dep. Variable:              dataset.y   R-squared:                       0.688
# Model:                            OLS   Adj. R-squared:                  0.666
# Method:                 Least Squares   F-statistic:                     30.89
# Date:                Thu, 04 Apr 2019   Prob (F-statistic):           7.06e-05
# Time:                        00:19:32   Log-Likelihood:                -47.669
# No. Observations:                  16   AIC:                             99.34
# Df Residuals:                      14   BIC:                             100.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
#Density plot
sns.distplot(dataset['y'], hist=True, kde=True, 
             bins=int(180/5), color = 'darkblue', 
             hist_kws={'edgecolor':'black'},
             kde_kws={'linewidth': 4})

# %%
from pandas import Series
from matplotlib import pyplot
series = Series.from_csv('C:/Users/omer qureshi/Downloads/Prob-8-1.csv', header=0)
series.plot()
pyplot.show()
# Out:
# C:\Users\omer qureshi\AppData\Roaming\Python\Python37\site-packages\pandas\core\series.py:4141: FutureWarning: from_csv is deprecated. Please use read_csv(...) instead. Note that some of the default arguments are different, so please refer to the documentation for from_csv when changing your function calls
#   infer_datetime_format=infer_datetime_format)

# %%
#Running autocorrelation function
from matplotlib import pyplot
from statsmodels.graphics.tsaplots import plot_acf
series = Series.from_csv('C:/Users/omer qureshi/Downloads/Prob-8-1.csv', header=0)
plot_acf(series)
pyplot.show()

# %%
#Running pairsplot
sns.pairplot(dataset)

# %%
data = np.random.randn(100)

with pm.Model() as model:
    mu = pm.Normal('mu', mu=0, sd=1, testval=0)
    sd = pm.HalfNormal('sd', sd=1)
    n = pm.Normal('n', mu=mu, sd=sd, observed=dataset)

    trace = pm.sample(5000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (2 chains in 2 jobs)
# NUTS: [sd, mu]
# Sampling 2 chains: 100%|█████████████████████████████████████████████████████| 11000/11000 [01:17<00:00, 141.86draws/s]

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x15619970>,
# ...
#       dtype=object)

# %%
ppc = pm.sample_posterior_predictive(trace, samples=500, model=model)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████| 500/500 [00:00<00:00, 1942.34it/s]

# %%
_, ax = plt.subplots(figsize=(12, 6))
ax.hist([n.mean() for n in ppc['n']], bins=19, alpha=0.5)
ax.axvline(data.mean())
ax.set(title='Posterior predictive of the mean', xlabel='mean(x)', ylabel='Frequency');

# %% [markdown]
# The inferred mean and actual mean are poles apart

# %%
multi_chain = trace[burnin:]
pm.gelman_rubin(multi_chain)
# Out:
# {'mu': 1.0000896986212824, 'sd': 0.9999589480455016}

# %%
pm.forestplot(multi_chain)
# Out:
# GridSpec(1, 2, width_ratios=[3, 1])

# %%
pm.summary(multi_chain)
# Out:
#         mean        sd  mc_error   hpd_2.5   hpd_97.5        n_eff      Rhat
# mu  4.930156  0.928734  0.011328  3.209590   6.844971  6492.088211  1.000090
# sd  9.265695  0.497365  0.005798  8.294328  10.253367  7214.895212  0.999959
